# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns

# %%
stops = pd.read_csv('../data/cleaned_stops.csv', parse_dates=['timestamp'])

# %%
stops.head(10)
# Out:
#    id  stop_id           stop_cause  service_area subject_race  subject_sex  \
# 0   0  1308198  Equipment Violation         530.0            W          1.0
# 1   1  1308172     Moving Violation         520.0            B          1.0
# 2   2  1308171     Moving Violation         110.0            H          0.0
# 3   3  1308170     Moving Violation           NaN            W          0.0
# 4   4  1308197     Moving Violation         230.0            W          1.0
# 5   5  1308200     Moving Violation         710.0            H          1.0
# 6   6  1308174     Moving Violation           NaN            O          1.0
# 7   7  1308199     Moving Violation         440.0            H          1.0
# 8   8  1308979     Moving Violation         310.0            H          0.0
# 9   9  1308965     Moving Violation         240.0            W          0.0
#
#    subject_age           timestamp  sd_resident  arrested  searched  \
# ...

# %%
stops.groupby(pd.Grouper(key='timestamp', freq='7d')).size().plot(figsize=(16,4));
